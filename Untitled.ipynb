# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
# !pip --proxy http://bloombecg:Dnpd12345@hkproxy01.int.clsa.com:8080/  install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org seaborn --upgrade

# %%
train_data = pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/test.csv")
train_data = train_data.drop(['Id'] , axis=1)

# %%
train_data.shape
# Out:
# (1460, 80)

# %%
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 1         Lvl    AllPub       FR2    ...            0    NaN   NaN
# 2         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 3         Lvl    AllPub    Corner    ...            0    NaN   NaN
# 4         Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         NaN       0      2    2008        WD         Normal     208500
# ...

# %%
desc = train_data.describe()
desc
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# 5             50         85.0    14115            5            5       1993
# 6             20         75.0    10084            8            5       2004
# 7             60          NaN    10382            7            6       1973
# 8             50         51.0     6120            7            5       1931
# 9            190         50.0     7420            5            6       1939
# 10            20         70.0    11200            5            5       1965
# ...

# %%
num_variables = desc.columns
cat_variables = [x for x in train_data.columns if x not in num_variables]
train_data.iloc[:,0]
# Out:
# 0        60
# 1        20
# 2        60
# 3        70
# 4        60
# 5        50
# 6        20
# 7        60
# 8        50
# 9       190
# 10       20
# 11       60
# 12       20
# 13       20
# 14       20
# 15       45
# 16       20
# 17       90
# 18       20
# 19       20
# 20       60
# 21       45
# 22       20
# 23      120
# 24       20
# 25       20
# 26       20
# 27       20
# 28       20
# 29       30
#        ...
# 1430     60
# 1431    120
# 1432     30
# 1433     60
# 1434     20
# 1435     20
# 1436     20
# 1437     20
# 1438     20
# 1439     60
# 1440     70
# 1441    120
# 1442     60
# 1443     30
# 1444     20
# 1445     85
# 1446     20
# 1447     60
# 1448     50
# 1449    180
# 1450     90
# 1451     20
# 1452    180
# 1453     20
# 1454     20
# 1455     60
# 1456     20
# 1457     70
# 1458     20
# 1459     20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
train_data['BsmtQual'].fillna("No" ,inplace = True)
sns.boxplot(x = 'BsmtQual' , y = 'SalePrice' , data=train_data).set_title('BsmtQual')
# Out:
# Text(0.5,1,'BsmtQual')

# %%
sns.scatterplot(x="LotArea", y="SalePrice", data=train_data);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-8508d48847c8> in <module>()
# ----> 1 sns.scatterplot(x="LotArea", y="SalePrice", data=train_data);
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
sns.__version__
# Out:
# '0.8.0'

# %%
train_data(['MSZoning','LotArea','Utilities','Neighborhood','OverallQual','OverallCond', 'YearBuilt', 'YearRemodAdd' ])
